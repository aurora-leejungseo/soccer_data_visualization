# %%
import os
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)
warnings.filterwarnings(action="ignore", message="credentials were not supplied. open data access only")
from tqdm import tqdm
import statsbombpy

# %%
# %reload_ext autoreload
# %autoreload 2
from socceraction.data.statsbomb import StatsBombLoader
import socceraction.spadl as spadl

# %%
#!pip install mplsoccer

# %%
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.image as mpimg 
import seaborn as sns

import matplotsoccer as mps
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch
import altair as alt

import warnings
warnings.filterwarnings("ignore")

# %%
SBL = StatsBombLoader(getter="remote", creds={"user": None, "passwd": None})

# %%
competitions = SBL.competitions()

# %%
competitions
# Out:
#     season_id  competition_id         competition_name  \
# 0           4              16         Champions League
# 1           1              16         Champions League
# 2           2              16         Champions League
# 3          27              16         Champions League
# 4          26              16         Champions League
# 5          25              16         Champions League
# 6          24              16         Champions League
# 7          23              16         Champions League
# 8          22              16         Champions League
# 9          21              16         Champions League
# 10         41              16         Champions League
# 11         39              16         Champions League
# 12         37              16         Champions League
# 13         44              16         Champions League
# 14         76              16         Champions League
# 15         90              37  FA Women's Super League
# 16         42              37  FA Women's Super League
# 17          4              37  FA Women's Super League
# 18          3              43           FIFA World Cup
# 19         90              11                  La Liga
# 20         42              11                  La Liga
# 21          4              11                  La Liga
# 22          1              11                  La Liga
# 23          2              11                  La Liga
# 24         27              11                  La Liga
# 25         26              11                  La Liga
# 26         25              11                  La Liga
# 27         24              11                  La Liga
# 28         23              11                  La Liga
# 29         22              11                  La Liga
# 30         21              11                  La Liga
# 31         41              11                  La Liga
# 32         40              11                  La Liga
# 33         39              11                  La Liga
# 34         38              11                  La Liga
# 35         37              11                  La Liga
# 36          3              49                     NWSL
# 37         44               2           Premier League
# 38         43              55                UEFA Euro
# 39         30              72        Women's World Cup
#
#                 country_name competition_gender season_name
# 0                     Europe               male   2018/2019
# 1                     Europe               male   2017/2018
# 2                     Europe               male   2016/2017
# 3                     Europe               male   2015/2016
# 4                     Europe               male   2014/2015
# 5                     Europe               male   2013/2014
# 6                     Europe               male   2012/2013
# 7                     Europe               male   2011/2012
# 8                     Europe               male   2010/2011
# 9                     Europe               male   2009/2010
# 10                    Europe               male   2008/2009
# 11                    Europe               male   2006/2007
# 12                    Europe               male   2004/2005
# 13                    Europe               male   2003/2004
# 14                    Europe               male   1999/2000
# 15                   England             female   2020/2021
# 16                   England             female   2019/2020
# 17                   England             female   2018/2019
# 18             International               male        2018
# 19                     Spain               male   2020/2021
# 20                     Spain               male   2019/2020
# 21                     Spain               male   2018/2019
# 22                     Spain               male   2017/2018
# 23                     Spain               male   2016/2017
# 24                     Spain               male   2015/2016
# 25                     Spain               male   2014/2015
# 26                     Spain               male   2013/2014
# 27                     Spain               male   2012/2013
# 28                     Spain               male   2011/2012
# 29                     Spain               male   2010/2011
# 30                     Spain               male   2009/2010
# 31                     Spain               male   2008/2009
# 32                     Spain               male   2007/2008
# 33                     Spain               male   2006/2007
# 34                     Spain               male   2005/2006
# 35                     Spain               male   2004/2005
# 36  United States of America             female        2018
# 37                   England               male   2003/2004
# 38                    Europe               male        2020
# 39             International             female        2019

# %%
selected_competitions = competitions[competitions.competition_name == "Premier League"]
selected_competitions
# Out:
#     season_id  competition_id competition_name country_name  \
# 37         44               2   Premier League      England
#
#    competition_gender season_name
# 37               male   2003/2004

# %%
games = pd.concat([
    SBL.games(row.competition_id, row.season_id)
    for row in selected_competitions.itertuples()
])

# %%
games_verbose = tqdm.tqdm(list(games.itertuples()), desc="Loading game data")
teams, players = [], []
actions = {}
for game in games_verbose:
    # load data
    teams.append(SBL.teams(game.game_id))
    players.append(SBL.players(game.game_id))
    events = SBL.events(game.game_id)
    # convert data
    actions[game.game_id] = spadl.statsbomb.convert_to_actions(events, game.home_team_id)

teams = pd.concat(teams).drop_duplicates(subset="team_id")
players = pd.concat(players)
# Out:
# Loading game data: 100%|████████████████████████| 33/33 [00:43<00:00,  1.32s/it]

# %%
datafolder = "data"

# Create data folder if it doesn't exist
if not os.path.exists(datafolder):
    os.mkdir(datafolder)
    print(f"Directory {datafolder} created.")

spadl_h5 = os.path.join(datafolder, "spadl-statsbomb.h5")

# Store all spadl data in h5-file
with pd.HDFStore(spadl_h5) as spadlstore:
    spadlstore["competitions"] = selected_competitions
    spadlstore["games"] = games
    spadlstore["teams"] = teams
    spadlstore["players"] = players[['player_id', 'player_name', 'nickname']].drop_duplicates(subset='player_id')
    spadlstore["player_games"] = players[['player_id', 'game_id', 'team_id', 'is_starter', 'starting_position_id', 'starting_position_name', 'minutes_played']]
    for game_id in actions.keys():
        spadlstore[f"actions/game_{game_id}"] = actions[game_id]

print(spadlstore)
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: data/spadl-statsbomb.h5

# %%
#Player Position Plot - combining
data = "data/spadl-statsbomb.h5"
games = pd.read_hdf(data,key="games")
epl16 = games[(games.competition_id == 2) & (games.season_id == 44)]

# %%
def get_actions(games, hdf_url):
    actions = []
    for game in tqdm(list(games.itertuples())):
        a = pd.read_hdf(hdf_url, key="actions/game_" + str(game.game_id))
        a["left_to_right"] = a["team_id"] == game.home_team_id
        actions.append(a)
    
    actions = pd.concat(actions)
    actions = always_ltr(actions)

    return actions


def always_ltr(actions):
    away_idx = ~actions.left_to_right
    actions.loc[away_idx, "start_x"] = 105 - actions[away_idx].start_x.values
    actions.loc[away_idx, "start_y"] = 68 - actions[away_idx].start_y.values
    actions.loc[away_idx, "end_x"] = 105 - actions[away_idx].end_x.values
    actions.loc[away_idx, "end_y"] = 68 - actions[away_idx].end_y.values
    return actions

actions = get_actions(epl16,data)
players = pd.read_hdf(data,key="players")
actions = actions.merge(players)

#sort player_name list for dropdown
player_name = list(set(actions.player_name))[0]

#for player position
pa = actions[actions.player_name.str.contains(player_name)]
x = pa.start_x
y = pa.start_y

#for player passing
pa2 = actions[actions.player_name.str.contains(player_name)]
pa2 = actions[actions["type_id"]==0]
x2 = pa2.start_x
y2 = pa2.start_y

#for player shot
pa3 = actions[actions.player_name.str.contains(player_name)]
pa3 = actions[actions["type_id"]==11]
x3 = pa3.start_x
y3 = pa3.start_y

#for player dribble
pa4 = actions[actions.player_name.str.contains(player_name)]
pa4 = actions[actions["type_id"]==21]
x4 = pa4.start_x
y4 = pa4.start_y

#call Pitch()
pitch = Pitch()
fig, ax = pitch.draw(nrows=2, ncols=2)

#try/except for players who don't have data for position/pass/shot/dribble
try:
    sns.kdeplot(x, y, cmap="Reds", shade=True, bw=.15, cbar=True, n_levels=6, ax=ax[0,0]).collections[0].set_alpha(0)
    sns.kdeplot(x2, y2, cmap="Blues", shade=True, bw=.15, cbar=True, n_levels=6, ax=ax[0,1]).collections[0].set_alpha(0)
    sns.kdeplot(x3, y3, cmap="YlOrBr", shade=True, bw=.15, cbar=True, n_levels=6, ax=ax[1,0]).collections[0].set_alpha(0)
    sns.kdeplot(x4, y4, cmap="Purples", shade=True, bw=.15, cbar=True, n_levels=6, ax=ax[1,1]).collections[0].set_alpha(0)
except:
    None

#set title
ax[0, 0].set_title('Position for '+ player_name)
ax[0, 1].set_title('Passing for '+ player_name)
ax[1, 0].set_title('Shot for '+ player_name)
ax[1, 1].set_title('Dribble for '+ player_name)

fig.tight_layout()
plt.show()
# Out:
# 100%|███████████████████████████████████████████| 33/33 [00:00<00:00, 77.62it/s]

# %%
#Player Position Plot 
data = "data/spadl-statsbomb.h5"
games = pd.read_hdf(data,key="games")
epl16 = games[(games.competition_id == 2) & (games.season_id == 44)]

def get_actions(games, hdf_url):
    actions = []
    for game in tqdm(list(games.itertuples())):
        a = pd.read_hdf(hdf_url, key="actions/game_" + str(game.game_id))
        a["left_to_right"] = a["team_id"] == game.home_team_id
        actions.append(a)
    
    actions = pd.concat(actions)
    actions = always_ltr(actions)

    return actions


def always_ltr(actions):
    away_idx = ~actions.left_to_right
    actions.loc[away_idx, "start_x"] = 105 - actions[away_idx].start_x.values
    actions.loc[away_idx, "start_y"] = 68 - actions[away_idx].start_y.values
    actions.loc[away_idx, "end_x"] = 105 - actions[away_idx].end_x.values
    actions.loc[away_idx, "end_y"] = 68 - actions[away_idx].end_y.values
    return actions

actions = get_actions(epl16,data)
players = pd.read_hdf(data,key="players")
actions = actions.merge(players)

# choose a player to visualize, feel free to change the index
player_name = sorted(list(set(actions.player_name)))
    
pa = actions[actions.player_name.str.contains(player_name)]

x = pa.start_x
y = pa.start_y

base = mps.field("green",figsize=8,show=False)
hmax = sns.kdeplot(x, y, cmap="Reds", shade=True, bw=.15, cbar=True, n_levels=6)
hmax.collections[0].set_alpha(0)


plt.title("Position Visualization for " + player_name)
plt.show()
# Out:
# 100%|███████████████████████████████████████████| 33/33 [00:00<00:00, 74.17it/s]
# Aaron Hughes
# Aaron Lennon
# Adrian Mutu
# Alain Goma
# Alan Shearer
# Alan Smith
# Alan Stubbs
# Alan Wright
# Alessandro Pistone
# Alex Rae
# Alexei Gennadyevich Smertin
# Aliou Cissé
# Amdy Moustapha Faye
# Andrew Davies
# Andy Cole
# Andy Melville
# Andy O"Brien
# Andy Todd
# Anthony Gardner
# Anthony Le Tallec
# Antoine Sibierski
# Antti Mikko Niemi
# Arjan de Zeeuw
# Ashley Cole
# Augustine Azuka "Jay-Jay" Okocha
# Barry Ferguson
# Barry Hayles
# Billy McKinlay
# Bobby Zamora
# Boris Živković
# Boudewijn Zenden
# Brad Friedel
# Brett Emerton
# Brett Ormerod
# Brian McBride
# Bruno N"Gotty
# Bryan Hughes
# Carl Cort
# Carlo Cudicini
# Carlos Manuel Bocanegra
# Carlton Cole Okirie
# Chris Baird
# Chris Perry
# Chris Riggott
# Claude Makélélé
# Claudio Reyna
# Claus Jensen
# Clinton Morrison
# Colin Cameron
# Colin Cooper
# Collins John
# Craig Bellamy
# Craig Short
# Cristiano Ronaldo dos Santos Aveiro
# Damien Duff
# Damien Johnson
# Danny Coyne
# Danny Higginbotham
# Danny Mills
# Danny Murphy
# Danny Tiatto
# Darren Ambrose
# Darren Anderton
# Darren Fletcher
# Darren Kenton
# David Batty
# David Dunn
# David James
# David Prutton
# David Seaman
# David Sommeil
# David Unsworth
# Dean Kiely
# Dean Richards
# Dean Sturridge
# Dejan Stefanovic
# Denis Irwin
# Dennis Bergkamp
# Diego Forlán Corazo
# Dietmar Hamann
# Dino Baggio
# Dominic Matteo
# Dorival Guidoni Júnior
# Dwight Yorke
# Eduardo César Daude Gaspar
# Edwin van der Sar
# Eiður Smári Guðjohnsen
# El-Hadji Ousseynou Diouf
# Emile Heskey
# Eric Daniel Djemba-Djemba
# Eyal Berkovic
# Fitz Hall
# Franck Queudrue
# Frank Lampard
# Frank Mohammed Sinclair
# Fredrik Ljungberg
# Frédéric Oumar Kanouté
# Gareth Barry
# Gareth Southgate
# Gary Naysmith
# Gary Neville
# Gary Oliver Kelly
# Gary Speed
# Gaël Clichy
# George Boateng
# Gilberto Aparecido da Silva
# Glen Johnson
# Graham Stuart
# Gustavo Augusto Poyet Domínguez
# Gérémi Sorele N"Djitap Fotso
# Harry Kewell
# Henri Camara
# Henrik Pedersen
# Hermann Hreidarsson
# Hernán Jorge Crespo
# Hugo Miguel Ferreira Gomes Viana
# Hélder Manuel Marques Postiga
# Ian Bennett
# Ian Harte
# Ian Pearce
# Ian Walker
# Ibrahim Ba
# Igor Bišćan
# Ioan Viorel Ganea
# Iván Campo Ramos
# Jamal Julian Campbell-Ryce
# James Beattie
# James Philip Milner
# James Scowcroft
# Jamie Carragher
# Jamie Clapham
# Jamie Redknapp
# Jason Joseph Euell
# Jason Roberts
# Jens Lehmann
# Jermain Defoe
# Jermaine Jenas
# Jermaine Pennant
# Jerrel Hasselbaink
# Jerzy Dudek
# Jesper Grønkjær
# Jihai Sun
# Jlloyd Tafari Samuel
# Jody Craddock
# Joe Cole
# Joey Barton
# John Arne Semundseth Riise
# John O"Shea
# John Terry
# John Welsh
# Johnnie Jackson
# Jonatan Lillebror Johansson
# Jonathan Douglas
# Jonathan Fortune
# Jonathan Woodgate
# Jordan Stewart
# Joseph Phillip Yobo
# Joseph-Desiré Job
# José Antonio Reyes Calderón
# José Vitor Roque Júnior
# Juan Pablo Ángel Arango
# Junichi Inamoto
# Jussi Jääskeläinen
# Jérémie Aliadière
# Jérôme Bonnissel
# Kasey Keller
# Kenny Cunningham
# Kenny Miller
# Kevin Cyril Davies
# Kevin Nolan
# Kevin Phillips
# Kieron Dyer
# Kolo Habib Touré
# Lamine Sakho
# Laureano Bisan-Etame Mayer
# Laurent Robert
# Ledley King
# Lee Bowyer
# Lee Clark
# Lee Hendrie
# Lee Naylor
# Liam Ridgewell
# Lilian Nalis
# Louis Saha
# Lucas Neill
# Lucas Radebe
# Luke Young
# Luís Boa Morte Pereira
# Léandre Griffit
# Maik Taylor
# Malcolm Christie
# Marcus Allbäck
# Marcus Bent
# Mario Melchiot
# Mark Anthony Delaney
# Mark Fish
# Mark Kennedy
# Mark Pembridge
# Mark Schwarzer
# Mark Viduka
# Markus Babbel
# Martin Andresen
# Martin Djetou
# Martin Keown
# Massimo Maccarone
# Matt Heath
# Matt Holland
# Matt Jansen
# Matthew Upson
# Mauricio Taricco
# Mbulelo Mabizela
# Michael Bridges
# Michael Brown
# Michael Duberry
# Michael Gray
# Michael Lennart Svensson
# Michael Oakes
# Michael Owen
# Michael Tarnat
# Mikael Forssell
# Mikaël Silvestre
# Milan Baroš
# Moritz Volz
# Neil Sullivan
# Neill McCann
# Nick Barmby
# Nick Chadwick
# Nicky Hunt
# Nicolas Anelka
# Nigel Quashie
# Nikos Dabizas
# Nwankwo Christian Kanu
# Ole Gunnar Solskjær
# Oleg Luzhny
# Olivier Bernard
# Olivier Tébily
# Olof Mellberg
# Oswaldo Giroldo Júnior
# Paolo Di Canio
# Pascal Cygan
# Patrick Vieira
# Patrik Berger
# Paul Bosvelt
# Paul Brooker
# Paul Butler
# Paul Dickov
# Paul Gallagher
# Paul Ince
# Paul Jones
# Paul Konchesky
# Paul Robinson
# Paul Scholes
# Paul Telfer
# Per Frandsen
# Peter Crouch
# Peter Whittingham
# Phil Neville
# Quinton Fortune Kolobea
# Radostin Kishishev
# Ray Parlour
# René Salomon Olembé-Olembé
# Ricardo Wayne Gardner
# Richard Dunne
# Richard Wright
# Rio Ferdinand
# Robbie Fowler
# Robbie Keane
# Robbie Savage
# Robert Huth
# Robert Pirès
# Rohan Ricketts
# Ronny Johnsen
# Rory Delap
# Roy Carroll
# Roy Keane
# Ruud van Nistelrooy
# Ryan Giggs
# Salif Alassane Diao
# Sami Hyypiä
# Scott Parker
# Sean Davis
# Seth Johnson
# Shaka Hislop
# Shaun Newton
# Shaun Wright-Phillips
# Shay Given
# Shola Ameobi
# Simon Charlton
# Simon Davies
# Simon Johnson
# Stan Lazaridis
# Steed Malbranque
# Steffen Freund
# Steffen Iversen
# Stephane Dalmat
# Stephen Carr
# Stephen Clemence
# Stephen Kelly
# Stern John
# Steve Finnan
# Steve McManaman
# Steve Stone
# Steve Watson
# Steven Caldwell
# Steven Gerrard
# Steven Reid
# Stewart Downing
# Stuart Parnaby
# Stylianos Giannakopoulos
# Sulzeer Jeremiah "Sol" Campbell
# Sylvain Distin
# Sylvain Legwinski
# Sylvain Wiltord
# Szilárd Németh
# Sébastien Schemmel
# Teddy Sheringham
# Thierry Henry
# Thomas Gravesen
# Thomas Hitzlsperger
# Thomas Løvendahl Sørensen
# Tie Li
# Tim Howard
# Titus Malachi Bramble
# Tobias Linderoth
# Tomasz Radziński
# Trevor Benjamin
# Trevor Sinclair
# Tugay Kerimoğlu
# Ugo Ehiogu
# Ulises Hernán de la Cruz Bernardo
# Vladimir Smicer
# Vratislav Greško
# Wayne Bridge
# Wayne Mark Rooney
# Wes Brown
# William Gallas
# Yakubu Aiyegbeni
# Youri Djorkaeff
# Zat Knight
# Zoumana Camara
# Émerson Augusto Thome
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/5z/c8_lcxln56s7bp2fwgmm4gsc0000gn/T/ipykernel_20799/75583327.py in <module>
#      34     print(each)
#      35
# ---> 36 pa = actions[actions.player_name.str.contains(player_name)]
#      37
#      38 x = pa.start_x
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py in contains(self, pat, case, flags, na, regex)
#    1151         dtype: bool
#    1152         """
# -> 1153         if regex and re.compile(pat).groups:
#    1154             warnings.warn(
#    1155                 "This pattern has match groups. To actually get the "
#
# ~/opt/anaconda3/lib/python3.9/re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ~/opt/anaconda3/lib/python3.9/re.py in _compile(pattern, flags)
#     292         flags = flags.value
#     293     try:
# --> 294         return _cache[type(pattern), pattern, flags]
#     295     except KeyError:
#     296         pass
#
# TypeError: unhashable type: 'list'

# %%
#Passing Vis
pa2 = actions[actions.player_name.str.contains(player_name)]
#filter only passing actions (==0)
pa2 = actions[actions["type_id"]==0]

x = pa2.start_x
y = pa2.start_y

base = mps.field("green",figsize=8,show=False)
hmax = sns.kdeplot(x, y, cmap="Blues", shade=True, bw=.15, cbar=True, n_levels=6)
hmax.collections[0].set_alpha(0)

plt.title("Passing Visualization for " + player_name)
plt.show()

# %%
#Shot Vis
pa3 = actions[actions.player_name.str.contains(player_name)]
#filter only passing actions (==0)
pa3 = actions[actions["type_id"]==11]

x = pa3.start_x
y = pa3.start_y

base = mps.field("green",figsize=8,show=False)
hmax = sns.kdeplot(x, y, cmap="YlOrBr", shade=True, bw=.15, cbar=True, n_levels=6)
hmax.collections[0].set_alpha(0)

plt.title("Shot Visualization for " + player_name)
plt.show()
# Out:
# /Users/hongjulee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/hongjulee/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.15 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
#Dribble Vis
pa4 = actions[actions.player_name.str.contains(player_name)]
pa4 = actions[actions["type_id"]==20]

x = pa4.start_x
y = pa4.start_y

base = mps.field("green",figsize=8,show=False)
hmax = sns.kdeplot(x, y, cmap="Purples", shade=True, bw=.15, cbar=True, n_levels=6)
hmax.collections[0].set_alpha(0)

plt.title("Dribble Visualization for " + player_name)
plt.show()
# Out:
#   0%|                                                    | 0/33 [00:00<?, ?it/s]
#  21%|█████████▎                                  | 7/33 [00:00<00:00, 65.40it/s]
#  45%|███████████████████▌                       | 15/33 [00:00<00:00, 68.97it/s]
#  70%|█████████████████████████████▉             | 23/33 [00:00<00:00, 70.39it/s]
# 100%|███████████████████████████████████████████| 33/33 [00:00<00:00, 69.46it/s]
# /Users/hongjulee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/hongjulee/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.15 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/5z/c8_lcxln56s7bp2fwgmm4gsc0000gn/T/ipykernel_17071/2094612210.py in <module>
#      43 base = mps.field("green",figsize=8,show=False)
#      44 hmax = sns.kdeplot(x, y, cmap="Purples", shade=True, bw=.15, cbar=True, n_levels=6)
# ---> 45 hmax.collections[0].set_alpha(0)
#      46
#      47 plt.title("Dribble Visualization for " + player_name)
#
# IndexError: list index out of range

# %%
actions[actions["type_id"] == 22]
# Out:
#        game_id                     original_event_id  period_id  time_seconds  \
# 12221  3749052  887bb629-e316-4309-8beb-c4d889765596          1         770.0
# 12228  3749052  69b23be0-1ae4-4d40-9e6e-d3f2839f377b          1        1312.0
# 12230  3749052  ec640769-f858-4247-a416-f868654834d2          1        1686.0
# 12236  3749052  49c591fe-2e9b-4c49-9474-1b051c8c617a          1        2369.0
# 12237  3749052  6b9c97dc-d9cb-4f0b-b4db-a43ac8e91337          1        2534.0
# ...        ...                                   ...        ...           ...
# 63368  3749403  fd605d39-8c8c-4d95-b6a7-0a0bb04aa46f          2         453.0
# 63373  3749403  a08a5ebb-64e5-4fe3-9401-866874f9c18e          2        1179.0
# 63374  3749403  9aa04dc3-83ad-4e6e-b6ec-0f15cd806edd          2        1305.0
# 63377  3749403  204a2283-6bf5-46aa-9827-dcac9bc723c3          2        1882.0
# 63389  3749403  38c8252e-acef-4b41-ba1d-5125cb3aacd4          2        2461.0
#
#        team_id  player_id   start_x    start_y      end_x      end_y  type_id  \
# 12221       46    40319.0  4.411765  37.873418  78.705882  46.136709       22
# 12228       46    40319.0  4.411765  37.873418  63.970588  47.083544       22
# 12230       46    40319.0  4.411765  37.873418  77.735294  47.341772       22
# 12236       46    40319.0  4.411765  37.873418  74.382353  57.412658       22
# 12237       46    40319.0  4.411765  30.987342  62.117647  43.468354       22
# ...        ...        ...       ...        ...        ...        ...      ...
# 63368      328    40385.0  4.411765  37.873418  67.676471  47.427848       22
# 63373      328    40385.0  4.411765  37.873418  73.764706  50.956962       22
# 63374      328    40385.0  4.411765  37.873418  70.852941  47.858228       22
# 63377      328    40385.0  4.411765  37.873418  57.882353  43.210127       22
# 63389      328    40385.0  4.411765  37.873418  69.705882  45.017722       22
#
#        result_id  bodypart_id  action_id  left_to_right         player_name  \
# 12221          0            0        261           True          Paul Jones
# 12228          0            0        399           True          Paul Jones
# 12230          1            0        501           True          Paul Jones
# 12236          1            0        718           True          Paul Jones
# 12237          0            0        773           True          Paul Jones
# ...          ...          ...        ...            ...                 ...
# 63368          1            0       1262          False  Jussi Jääskeläinen
# 63373          0            0       1484          False  Jussi Jääskeläinen
# 63374          1            0       1522          False  Jussi Jääskeläinen
# 63377          0            0       1723          False  Jussi Jääskeläinen
# 63389          0            0       1904          False  Jussi Jääskeläinen
#
#       nickname
# 12221     None
# 12228     None
# 12230     None
# 12236     None
# 12237     None
# ...        ...
# 63368     None
# 63373     None
# 63374     None
# 63377     None
# 63389     None
#
# [568 rows x 17 columns]

# %%
player_name
# Out:
# 'Aaron Hughes'

# %%
data = "data/spadl-statsbomb.h5"
games = pd.read_hdf(data,key="games")
epl16 = games[(games.competition_id == 2) & (games.season_id == 44)]


def get_actions(games, hdf_url):
    actions = []
    for game in tqdm(list(games.itertuples())):
        a = pd.read_hdf(hdf_url, key="actions/game_" + str(game.game_id))
        a["left_to_right"] = a["team_id"] == game.home_team_id
        actions.append(a)
    
    actions = pd.concat(actions)
    actions = always_ltr(actions)

    return actions


def always_ltr(actions):
    away_idx = ~actions.left_to_right
    actions.loc[away_idx, "start_x"] = 105 - actions[away_idx].start_x.values
    actions.loc[away_idx, "start_y"] = 68 - actions[away_idx].start_y.values
    actions.loc[away_idx, "end_x"] = 105 - actions[away_idx].end_x.values
    actions.loc[away_idx, "end_y"] = 68 - actions[away_idx].end_y.values
    return actions

actions = get_actions(epl16,data)
players = pd.read_hdf(data,key="players")
actions = actions.merge(players)

# choose a player to visualize, feel free to change the index
player_name = list(set(actions.player_name))[0]

pa = actions[actions.player_name.str.contains(player_name)]

x = pa.start_x
y = pa.start_y

mps.field("green",figsize=8,show=False)
    
plt.scatter(x,y)
plt.axis("on")
plt.title("position visualization for " + player_name)
plt.show()
# Out:
#   0%|                                                    | 0/33 [00:00<?, ?it/s]
#  21%|█████████▎                                  | 7/33 [00:00<00:00, 68.48it/s]
#  45%|███████████████████▌                       | 15/33 [00:00<00:00, 71.74it/s]
#  70%|█████████████████████████████▉             | 23/33 [00:00<00:00, 73.73it/s]
# 100%|███████████████████████████████████████████| 33/33 [00:00<00:00, 73.25it/s]
